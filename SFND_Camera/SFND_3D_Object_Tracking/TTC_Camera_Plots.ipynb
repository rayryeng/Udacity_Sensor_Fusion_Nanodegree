# %% [markdown]
# # TTC Camera Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# # Shi-Tomasi Results

# %%
brisk_ttc_times = [12.6664, 12.1911, 19.9567, 13.3053, 14.5929, 69.667, 14.2257, 14.2028, 12.6506, 13.025, 10.1893, 10.4153, 13.3443, 10.2157, 8.31584, 9.89771, 11.4934, 7.96087]
brief_ttc_times = [15.3278, 12.5269, 11.8911, 10.9635, 17.3304, 17.284, 12.2519, 17.1529, 11.9423, 14.2414, 10.701, 10.4426, 11.8542, 12.344, 9.96343, 12.8723, 10.6946, 8.27744]
orb_ttc_times = [16.2413, 12.189, 14.186, 12.6743, 23.026, 26.465, 14.7796, 14.2933, 10.7454, 20.6906, 10.6102, 10.7673, 13.176, 10.8113, 7.91087, 10.7351, 10.3773, 7.9421]
freak_ttc_times = [12.9494, 14.3031, 13.8282, 13.4653, 43.3766, 30.9874, 13.9309, 12.1804, 11.9559, 13.2948, 10.1518, 12.2542, 12.6338, 10.9202, 9.16267, 9.67198, 12.1119, 7.10899]
sift_ttc_times = [15.3809, 12.391, 13.4042, 11.8396, 14.6598, 15.1537, 12.0143, 14.5144, 11.9786, 17.5439, 11.7821, 10.846, 11.7264, 10.2351, 10.1712, 10.4497, 10.5948, 8.19576]
indices = np.arange(1, 19)

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, orb_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'ORB', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - Shi-Tomasi Detector')
plt.savefig('images/report_images/shitomasi.png')

# %% [markdown]
# # Harris Results

# %%
brisk_ttc_times = [8.81332, 10.1951, -80.8541, 12.117, 44.9165, 14.6179, -np.nan, 12.3726, -np.nan, -0.1, -3.30025, 9.45845, -np.nan, 12.1403, -24.0917, 7.0948, -0.1, -0.1]
brief_ttc_times = [8.81332, 10.1951, -10.295, 12.7502, 12.5334, -np.nan, 37.5985, 17.2911, -np.nan, -np.nan, -np.nan, 7.91804, -36.977, 10.3726, -8.01809, 7.30238, -0.1, 9.45185]
orb_ttc_times = [-np.nan, 15.8258, -10.7212, 12.7502, -np.nan, 19.4172, -np.nan, 12.3726, -np.nan, -np.nan, -18.6635, 7.64707, -np.nan, 12.1403, -7.1346, 7.0948, -np.nan, -0.1]
freak_ttc_times = [-np.nan, -np.nan, 10.1951, -0.1, 12.7502, 10.774, 13.6216, -np.nan, 12.3726, -np.nan, -0.1, -np.nan, 9.80653, -np.nan, 12.1403, -5.91288, 8.96305, -0.1]
sift_ttc_times = [-np.nan, -np.nan, -58.2846, 40.7748, 13.6431, -np.nan, -np.nan, 12.3726, 9.57352, -np.nan, -np.nan, 10.0996, -np.nan, 18.5408, -24.0917, 7.29305, 1.25385, 9.45185]

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, orb_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'ORB', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - Harris Detector')
plt.savefig('images/report_images/harris.png')

# %% [markdown]
# # FAST Results

# %%
brisk_ttc_times = [17.3803, 20.5613, 14.1668, 26.3934, -np.nan, -np.nan, -np.nan, 12.306, 19.5831, 139.461, 13.2069, 12.664, 12.4425, 12.981, 10.8658, 11.9516, 9.86454, 11.9943]
brief_ttc_times = [12.3974, 12.8061, 11.879, 15.7034, -np.nan, 33.8496, 88.5715, 10.9688, 33.8551, 21.7164, 16.3323, 11.4879, 11.6463, 11.5009, 10.4316, 10.4518, 8.59154, 11.3468]
orb_ttc_times = [14.4104, 39.513, 18.5823, 27.752, -np.nan, 60.2673, 62.5083, 11.8211, 64.852, 36.4374, 14.3796, 14.5071, 13.4029, 11.4823, 12.2078, 11.7539, 10.911, 11.0002]
freak_ttc_times = [11.0842, 136.711, 11.4776, 18.3297, -np.nan, 13.998, 13.995, 13.5495, 16.1668, -np.nan, 12.2032, 14.8679, 13.3995, 11.9532, 8.98301, 11.7451, 10.2309, 12.186]
sift_ttc_times = [66.5182, 51.2, 14.1764, 51.1002, 260.193, 25.3035, 37.3043, 14.9189, 51.7847, 21.5668, 16.7097, 12.2394, 12.9602, 11.7539, 11.1735, 10.7084, 8.51056, 10.4058]

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, orb_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'ORB', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - FAST Detector')
plt.savefig('images/report_images/fast.png')

# %% [markdown]
# # BRISK Results

# %%
brisk_ttc_times = [12.8881, 23.71, 14.0968, 16.2781, 25.796, 17.3612, 15.5207, 16.2303, 15.8701, 12.8664, 11.3918, 10.9415, 12.1074, 12.1435, 12.2879, 11.063, 9.00722, 12.0767]
brief_ttc_times = [14.5177, 11.9825, 15.5934, 17.1571, 14.5595, 15.7657, 15.2976, 15.5184, 17.9508, 11.2434, 11.9367, 13.2237, 12.3197, 11.7254, 10.9284, 9.46945, 8.56715, 10.5862]
orb_ttc_times = [12.4942, 22.3042, 15.1926, 13.2436, 20.232, 21.5584, 14.526, 14.4969, 17.7586, 12.1233, 11.1979, 14.1767, 11.2089, 12.3195, 10.9619, 11.1281, 8.06543, 12.439]
freak_ttc_times = [14.0968, 23.5344, 14.0652, 15.2359, 22.9775, 15.5774, 19.8013, 16.7809, 15.961, 13.9313, 12.4801, 11.7053, 11.8425, 11.5114, 12.1083, 9.88605, 8.81934, 10.2839]
sift_ttc_times = [15.3668, 17.9251, 17.2697, 15.1556, 42.6012, 15.4771, 16.3978, 15.7031, 17.3713, 14.3956, 12.2912, 12.1758, 14.5383, 12.1395, 14.0086, 10.3521, 9.02807, 11.2251]

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, orb_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'ORB', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
_ = plt.title('Camera-based TTC - BRISK Detector')
plt.savefig('images/report_images/brisk.png')

# %% [markdown]
# # ORB Results

# %%
brisk_ttc_times = [11.7369, 54.169, 24.2424, 20.162, -np.nan, 18.2401, -np.nan, 10.7914, -np.nan, -np.nan, 8.104, -np.nan, 11.9236, 11.5726, 11.564, 12.5411, 15.8548, 27.1116]
brief_ttc_times = [13.8396, 18.1981, 26.1768, 20.3651, 132.25, 9.69176, -np.nan, 107.121, -np.nan, 46.7332, 19.4803, 16.1596, 24.9758, 15.682, 13.699, 8.9087, 20.1596, 13.8593]
orb_ttc_times = [9.36438, -np.nan, 23.9435, 35.3577, 146.628, -np.nan, -np.nan, -np.nan, -np.nan, 34.3415, 9.15807, -np.nan, 39.4535, 161.288, -np.nan, 14.0379, 11.789, 28.0396]
freak_ttc_times = [7.73222, -np.nan, 15.6437, 10.8599, -np.nan, 10.1262, -np.nan, 11.7737, -np.nan, -np.nan, 8.46718, 21.7524, 6.9029, 18.4901, 11.9016, 6.05322, 10.4695, 6.56103]
sift_ttc_times = [10.5394, 24.7876, 12.6004, 52.9083, 103.092, -np.nan, -np.nan, 11.683, -np.nan, -np.nan, 9.74456, -np.nan, 8.54081, 15.8959, 22.7945, 8.68674, 11.7043, 14.211]

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, orb_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'ORB', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - ORB Detector')
plt.savefig('images/report_images/orb.png')

# %% [markdown]
# # AKAZE Results

# %%
akaze_ttc_times = [12.5484, 14.3045, 13.1011, 14.8104, 14.1087, 15.0374, 16.1248, 14.1406, 14.9439, 12.1245, 12.3061, 11.5511, 10.894, 10.7242, 9.87058, 9.87802, 9.13802, 9.205]

# %%
plt.plot(indices, akaze_ttc_times)
plt.legend(['AKAZE'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - AKAZE Detector')
plt.savefig('images/report_images/akaze.png')

# %% [markdown]
# # SIFT Results

# %%
brisk_ttc_times = [12.6775, 13.3734, 13.8946, 17.999, 15.134, 12.0407, 15.2526, 14.1348, 13.9265, 11.3858, 11.9177, 10.2154, 8.73741, 8.89755, 8.58319, 8.5199, 8.79493, 8.74916]
brief_ttc_times = [12.1303, 13.188, 14.8269, 19.062, 14.9067, 12.7324, 15.3573, 14.8455, 12.4318, 11.2566, 12.2326, 11.0739, 9.12509, 9.21693, 8.36143, 8.27328, 8.50565, 9.09285]
freak_ttc_times = [14.0954, 13.2121, 13.3802, 17.4934, 15.3931, 11.9253, 17.3577, 15.1772, 13.4334, 12.2515, 13.0743, 10.4165, 8.88595, 9.01284, 9.83932, 8.39398, 8.73904, 9.23876]
sift_ttc_times = [11.7637, 12.9428, 13.0353, 16.3699, 13.7816, 11.7743, 13.905, 14.0628, 13.4334, 11.2617, 11.1724, 10.4327, 8.79125, 8.98301, 8.7324, 8.40205, 8.21647, 7.98618]

# %%
plt.plot(indices, brisk_ttc_times)
plt.plot(indices, brief_ttc_times)
plt.plot(indices, freak_ttc_times)
plt.plot(indices, sift_ttc_times)
plt.legend(['BRISK', 'BRIEF', 'FREAK', 'SIFT'])
plt.xlabel('Frame #')
plt.ylabel('TTC (in seconds)')
plt.xticks(indices)
plt.grid('on')
plt.title('Camera-based TTC - SIFT Detector')
plt.savefig('images/report_images/sift.png')
